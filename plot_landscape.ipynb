# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Tạo lưới 2D
x = np.linspace(-5, 5, 200)
y = np.linspace(-5, 5, 200)
X, Y = np.meshgrid(x, y)

# Các hàm landscape có đáy nhọn (giống thạch nhũ)
def stalactite(x0, y0, depth=5, sharpness=2):
    return -depth * np.exp(-sharpness * ((X - x0)**2 + (Y - y0)**2))

Z1 = stalactite(0, 0, depth=4, sharpness=1)        # Đáy giữa
Z2 = stalactite(2, 2, depth=3, sharpness=2)        # Đáy góc trên
Z3 = stalactite(-2, -2, depth=5, sharpness=1.5)    # Đáy góc dưới

# Vẽ 3D
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Vẽ từng bề mặt
ax.plot_surface(X, Y, Z1, cmap='Reds', alpha=0.5, edgecolor='none')
ax.plot_surface(X, Y, Z2, cmap='Greens', alpha=0.5, edgecolor='none')
ax.plot_surface(X, Y, Z3, cmap='Blues', alpha=0.5, edgecolor='none')

# Nhãn và tiêu đề
ax.set_title("3 Optimization Landscapes với đáy hình thạch nhũ")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Cost")

# Góc nhìn
ax.view_init(elev=50, azim=135)

plt.tight_layout()
plt.show()
